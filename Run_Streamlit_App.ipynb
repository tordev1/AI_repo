# %% [markdown]
# # Run Student Success Copilot (Streamlit App)
#
# This notebook clones the repo and runs the full Streamlit app in Colab
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/tordev1/Ai_repo/blob/main/Run_Streamlit_App.ipynb)

# %%
# !git clone https://github.com/tordev1/Ai_repo.git
# %cd Ai_repo
# !pip install -r requirements.txt

# %% [markdown]
# ## Step 2: Generate Data & Train Model
#
# The ML model needs to be trained before running the app. The cells below will generate the synthetic student data and train the predictive model.

# %%
# !python ai/data_generator.py
# !python ai/ml_model.py

# %% [markdown]
# ## Step 3: Run the Streamlit App
#
# Streamlit will run via a public tunnel using **pyngrok**. After running the cell below, click the generated **NgrokTunnel** URL to open the app in your browser.

# %%
# !pip install pyngrok

from pyngrok import ngrok
import subprocess
import time

# Set auth token
ngrok.kill()
ngrok.set_auth_token("3B79BU5EVVSseYMZebZhX4Ms7zc_5mi9E3D4syHwJFKJ7QL9P")

# Start Streamlit in background
proc = subprocess.Popen(
    ["streamlit", "run", "app.py", "--server.port", "8501", "--server.headless", "true"],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE
)

time.sleep(5)

# Create tunnel with your domain
public_url = ngrok.connect(8501, domain="unpostered-amiee-pangenetically.ngrok-free.dev")
print(f"\n✅ App is live! Click this link to open:\n")
print(f"👉 https://unpostered-amiee-pangenetically.ngrok-free.dev\n")

# %% [markdown]
# ## Instructions
#
# 1. Run all cells above in order
# 2. Click **https://unpostered-amiee-pangenetically.ngrok-free.dev** to open the app
# 3. If the tunnel expires, just re-run the last code cell
